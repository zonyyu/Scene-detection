# %% [markdown]
# # Scene Classifier
#
# This is my attempt to train a neural network made from scratch on a data set of different sceneries.

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## Loading the data set
#
# This will take a moment to load, as there are around 14,000 images to load and resize...

# %%
X_train, Y_train, X_test, Y_test = load_data("Dataset")
# Out:
# Loading from train set...
# Loading from test set...
# Stacking...
# (14034, 12288)
# Shuffling...
# Done
# (12288, 14034)

# %%
test_index = 10
plt.imshow(X_train[:, test_index].reshape(100, 100, 3))
plt.show()
classes = ["buildings", "forest", "glacier",
             "mountain", "sea", "street"]
print(classes[np.argmax(Y_train[:, test_index])])
# Out:
# buildings
